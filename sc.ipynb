# %%
import requests 
from instabot import Bot 
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service as ChromeService 
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.by import By
import os
import re
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup 
import time 
from selenium.webdriver.support.expected_conditions import visibility_of_element_located
options = webdriver.ChromeOptions() 

# run browser in headless mode 
options.headless= True 

# instantiate driver 
driver = webdriver.Chrome(service=ChromeService( 
    ChromeDriverManager().install()), options=options) 
url = 'https://www.linkedin.com/login?fromSignIn=true&trk=\guest_homepage-basic_nav-header-signin' 
driver.get(url) 
#time.sleep(5)
USERNAME = "hrithikpaul2001@gmail.com"
PASSWORD ="hrithik@123"
elementID = driver.find_element(By.ID,'username')
elementID.send_keys(USERNAME)
elementID = driver.find_element(By.ID,'password')
elementID.send_keys(PASSWORD)
elementID.submit()


profile_url = "https://www.linkedin.com/company/tata-communication/"
 
driver.get(profile_url) 
title = (
    WebDriverWait(driver=driver, timeout=10)
    .until(visibility_of_element_located((By.CSS_SELECTOR, "li")))
    .text
)
ps=BeautifulSoup(driver.page_source,"html5lib")##post scraping
connections=ps.find_all("span",{"class":"link-without-visited-state"})
social_reaction_counts_all_newly_post=ps.find_all("span",{"class":"social-details-social-counts__reactions-count"})
print(social_reaction_counts_all_newly_post)
social_comments_counts_all_newly_posts=ps.find_all("button",{"class":"t-black--light social-details-social-counts__count-value t-12 hoverable-link-text"})
print(social_comments_counts_all_newly_posts)
followers_count=ps.find_all("div",{"class":"org-top-card-summary-info-list__info-item"})
print(followers_count)
#name = ps.find_all('div',{"class":"ph5"})
x=connections[0]
# Out:
# [<span aria-hidden="true" class="social-details-social-counts__reactions-count">
# 3                </span>, <span aria-hidden="true" class="social-details-social-counts__reactions-count">
# 201                </span>]
# [<button aria-label="2 comments on Tata Communications’ post" class="t-black--light social-details-social-counts__count-value t-12 hoverable-link-text" role="link" type="button">
#                 <span aria-hidden="true">
#                     2 comments
#                                   </span>
#               </button>]
# [<div class="org-top-card-summary-info-list__info-item">
#           Telecommunications
#         </div>, <div class="org-top-card-summary-info-list__info-item">
#             Mumbai, Maharashtra
#           </div>, <div class="org-top-card-summary-info-list__info-item">
#               559,520 followers
#             </div>]

# %%
print(x)
# Out:
# <span class="link-without-visited-state">
#                   <span class="t-bold">500+</span> connections
#                 </span>

# %%
connections=str(x)
finding_word_t_bold=connections.find("t-bold")
print(connections[81:84])
# Out:
# 500

# %%
for m in social_reaction_counts_all_newly_post:
    m=str(m)
    reactions_index=m.find("count")
    print(int(m[reactions_index+25:-7]))
# Out:
# 3
# 201

# %%
print(followers_count)
# Out:
# [<div class="org-top-card-summary-info-list__info-item">
#           Telecommunications
#         </div>, <div class="org-top-card-summary-info-list__info-item">
#             Mumbai, Maharashtra
#           </div>, <div class="org-top-card-summary-info-list__info-item">
#               559,520 followers
#             </div>]

# %%
index_for_followers=str(followers_count[0]).find("item")
print(index_for_followers)
followers_text=""
for i in followers_count:
    if "followers" in str(i):
        #print(str(i[index_for_followers:]))
        followers_text=str(i)
follwers=followers_text[index_for_followers+6:-18].strip()
print(follwers[:-10])
# Out:
# 49
# 559,520

# %%
total_followers=""
for i in follwers[:-10]:
    print(i)
    if i!=",":
        total_followers+=str(i)
print(int(total_followers))
# Out:
# 5
# 5
# 9
# ,
# 5
# 2
# 0
# 559520

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from time import sleep
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService 
from bs4 import BeautifulSoup  
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.expected_conditions import visibility_of_element_located

username = "hrithikpaul2001@gmail.com"
password = "hrithik@123"
phone="6296821825"
#options=Options()
options = webdriver.ChromeOptions() 

# run browser in headless mode 
options.headless= True 

# instantiate driver 
driver = webdriver.Chrome(service=ChromeService( 
    ChromeDriverManager().install()), options=options) 
actions = ActionChains(driver)

driver.get("https://twitter.com/login")
sleep(4)
try:
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div/div/div/div[5]/label/div/div[2]/div/input').send_keys(username)
    sleep(4)
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div/div/div/div[6]/div').click()
    sleep(4)
    driver.find_element(By.XPATH, '/html/body/div/div/div/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[2]/label/div/div[2]/div/input').send_keys(phone)
    sleep(4)
    driver.find_element(By.XPATH, '/html/body/div/div/div/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div').click()
    sleep(4)
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[3]/div/label/div/div[2]/div[1]/input').send_keys(password)
    sleep(4)
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div/div').click()
    sleep(4)
except:
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div/div/div/div[5]/label/div/div[2]/div/input').send_keys(username)
    sleep(4)
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div/div/div/div[6]/div').click()
    sleep(4)
   # driver.find_element(By.XPATH, '/html/body/div/div/div/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[2]/label/div/div[2]/div/input').send_keys(phone)
    #sleep(4)
    #driver.find_element(By.XPATH, '/html/body/div/div/div/div[1]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div/div/div/div').click()
    #sleep(4)
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div/div[3]/div/label/div/div[2]/div[1]/input').send_keys(password)
    sleep(4)
    driver.find_element(By.XPATH, '//*[@id="layers"]/div/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div[1]/div/div/div/div').click()
    sleep(4)
    
driver.get("https://twitter.com/TCS")
sleep(4)
ps=BeautifulSoup(driver.page_source,"html5lib")
followers_of_twitter_tag=ps.find_all("span",{"class":"css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0"})
print(followers_of_twitter_tag)
#posts_details_with_tag=ps.find_all("span",{"class":"css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0"})

#print(posts_details_with_tag)
# Out:
# [<span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">To view keyboard shortcuts, press question mark</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">View keyboard shortcuts</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">11</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">Tata Consultancy Services</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">See new posts</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">Follow</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;"><span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">Tata Consultancy Services</span><span class="css-901oao css-16my406 r-poiln
# ...

# %%
print(followers_of_twitter_tag)
# Out:
# [<span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">To view keyboard shortcuts, press question mark</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">View keyboard shortcuts</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">11</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">Tata Consultancy Services</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">See new posts</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">Follow</span>, <span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;"><span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">Tata Consultancy Services</span><span class="css-901oao css-16my406 r-poiln
# ...

# %%
for i in range(len(followers_of_twitter_tag)):
    finding=str(followers_of_twitter_tag[i])
    finding_index=finding.find("unset")
    if "Posts" in finding[finding_index+8:-7]:
        break
#print(followers_of_twitter_tag[i])
numbers=[]
for j in range(i,len(followers_of_twitter_tag)):
    finding=str(followers_of_twitter_tag[j])
    finding_index=finding.find("unset")
    val=finding[finding_index+8:-7]
    try:
        val=int(val)
        numbers.append(val)
    except:
        continue
print(numbers)
posts_reactions={"comment":0,"retweet":0,"like":0}
s=0 
for j in range(len(numbers)):
    if s==0:
        posts_reactions["comment"]+=numbers[j]
        s+=1
    elif s==1:
        posts_reactions["retweet"]+=numbers[j]
        s+=1 
    elif s==2:
        posts_reactions["like"]+=numbers[j]
        s=0
print(posts_reactions)
    #print(finding[finding_index+8:-7])
# Out:
# [2, 16, 34, 2, 7, 26, 74, 169]
# {'comment': 78, 'retweet': 192, 'like': 60}

# %%
for j in range(len(followers_of_twitter_tag)):
    x=str(followers_of_twitter_tag[j])
    find_unset=x.find("unset")
    main_text=x[find_unset+8:-7]
    #main_part.append(main_text)
    if "Followers" in x:
       # print(x)
        break 
followers_twitter=str(followers_of_twitter_tag[j-1]) 
followers_twitter=followers_twitter[94:-7]
if "K" in followers_twitter:
    followers_twitter=float(followers_twitter[:-1])*1000
print(followers_twitter)


    #main_part.append(x[find_unset+8:-7])
# Out:
# 565400.0

# %%
for i in range(len(main_part)):
    if "Followers" in main_part[i] or "follwers" in main_part[i]:
        break 
print(main_part[i])
# Out:
# Followers

# %%
print(main_part)
# Out:
# ['To view keyboard shortcuts, press question mark', 'View keyboard shortcuts', '11', 'Tata Communications', 'See new posts', 'Follow', '<span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;">Tata Communications</span><span class="css-901oao css-16my406 r-poiln3 r-bcqeeo r-1pos5eu r-qvutc0" style="text-overflow: unset;"><span class="css-901oao css-16my406 r-xoduu5 r-18u37iz r-1q142lx r-poiln3 r-adyw6z r-135wba7 r-bcqeeo r-qvutc0" style="text-overflow: unset;"><span class="css-901oao css-16my406 r-1awozwy r-xoduu5 r-poiln3 r-bcqeeo r-qvutc0" style="text-overflow: unset;"><div class="css-1dbjc4n r-xoduu5"><div aria-label="Provides details about verified accounts." class="css-18t94o4 css-1dbjc4n r-6koalj r-9cviqr r-1ny4l3l r-o7ynqc r-6416eg" role="button" tabindex="0"><svg aria-label="Verified account" class="r-1cvl2hr r-4qtqp9 r-yyyyoo r-1xvli5t r-f9ja8p r-og9te1 r-bnwqim r-1plcrui r-lrvibr" data-testid="icon-verified" role="img" viewBox="0 0 22 22
# ...

# %%
print(ps)
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
#     <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
#
#     <title>Sayani Ghatak | LinkedIn</title>
#
#     <meta charset="utf-8"/>
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta class="mercado-icons-sprite" content="https://static.licdn.com/aero-v1/sc/h/5rd8ti2rimm31ybs5mjbb1cnl" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
#     <meta content="" name="description"/>
#     <meta content="notranslate" name="google"/>
#     <meta content="voyager-web" name="service"/>
#     <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
#     <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# ...
